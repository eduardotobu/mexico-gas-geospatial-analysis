# %%
import pandas as pd

# %%
df
# Out:
#        place_id gas_type  price                               name  \
# 0         11703  regular  22.95   SERVICIO LAS TORRES SUR SA DE CV
# 1         11703  premium  27.90   SERVICIO LAS TORRES SUR SA DE CV
# 2         11702  regular  24.70        VIGO HIDROCARBUROS SA DE CV
# 3         11702  premium  30.30        VIGO HIDROCARBUROS SA DE CV
# 4         11702   diesel  27.99        VIGO HIDROCARBUROS SA DE CV
# ...         ...      ...    ...                                ...
# 36946     30363   diesel  26.99  SERVICIO TRECE Y CARRERA SA DE CV
# 36947     30362  regular  23.43                    GAZPRO SA DE CV
# 36948     30362  premium  28.02                    GAZPRO SA DE CV
# 36949     30442  regular  23.99                    GAZPRO SA DE CV
# 36950     30442  premium  27.48                    GAZPRO SA DE CV
#
#                        cre_id  longitude  latitude       date
# 0         PL/9999/EXP/ES/2015 -101.66340  21.14916 2026-05-23
# ...

# %%
df['name'].value_counts()
# Out:
# name
# SERVICIOS GASOLINEROS DE MEXICO SA DE CV             1376
# PETROMAX SA DE CV                                     665
# SERVICIO FACIL DEL SURESTE SA DE CV                   314
# MEGA GASOLINERAS SA DE CV                             272
# ENERGIA Y SERVICIOS COORDINADOS SA DE CV              255
#                                                      ...
# ESTACION DE SERVICIO DE SISAL SA DE CV                  1
# IRMA YOLANDA SOLIS BARRERA                              1
# GP GASOLINERA PERINORTE SA DE CV                        1
# CORPORATIVO DE MULTISERVICIOS NACIONALES SA DE CV       1
# FRANSA GAS SA DE CV                                     1
# Name: count, Length: 8189, dtype: int64

# %%
df = pd.read_parquet("../data/interim/gas_prices_2026-05-23.parquet")

df.dtypes
# Out:
# place_id              int64
# gas_type                str
# price               float64
# name                    str
# cre_id                  str
# longitude           float64
# latitude            float64
# date         datetime64[us]
# dtype: object
